# %%
import pandas as pd

# %%
df =pd.read_csv("train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
new_df = df[["PassengerId" , "Age" , "Survived" , "Pclass" , "Fare"]]

# %%
new_df.corr()
# Out:
#              PassengerId       Age  Survived    Pclass      Fare
# PassengerId     1.000000  0.036847 -0.005007 -0.035144  0.012658
# Age             0.036847  1.000000 -0.077221 -0.369226  0.096067
# Survived       -0.005007 -0.077221  1.000000 -0.338481  0.257307
# Pclass         -0.035144 -0.369226 -0.338481  1.000000 -0.549500
# Fare            0.012658  0.096067  0.257307 -0.549500  1.000000

# %% [markdown]
# <h1>.RENAME</h1>

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.rename(columns={"Name":"name_1"})
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                 name_1     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.rename(columns=str.lower)
# Out:
#      passengerid  survived  pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   name     sex   age  sibsp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
def reducer(string):
    return string[0].upper()



df.rename(columns=reducer)
# Out:
#        P  S  P                                                  N       S  \
# 0      1  0  3                            Braund, Mr. Owen Harris    male
# 1      2  1  1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2      3  1  3                             Heikkinen, Miss. Laina  female
# 3      4  1  1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4      5  0  3                           Allen, Mr. William Henry    male
# ..   ... .. ..                                                ...     ...
# 886  887  0  2                              Montvila, Rev. Juozas    male
# 887  888  1  1                       Graham, Miss. Margaret Edith  female
# 888  889  0  3           Johnston, Miss. Catherine Helen "Carrie"  female
# 889  890  1  1                              Behr, Mr. Karl Howell    male
# 890  891  0  3                                Dooley, Mr. Patrick    male
#
#         A  S  P                 T        F     C  E
# ...

# %%
def reindex_(data):
    if data==0:
        return 1
    else:
        return data
    

df.rename(index=reindex_)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# <h1>.REPLACE</h1>

# %%
import pandas as pd

# Sample DataFrame
df = pd.DataFrame({
    'A': [1, 2, 3, 4],
    'B': [4, 3, 2, 1]
})

# %%
df
# Out:
#    A  B
# 0  1  4
# 1  2  3
# 2  3  2
# 3  4  1

# %%
#  replacing all rows value
df_replaced = df.replace(1, 100)
df_replaced
# Out:
#      A    B
# 0  100    4
# 1    2    3
# 2    3    2
# 3    4  100

# %%
# multiple values
df_replaced = df.replace([1, 4], [100, 400])
df_replaced
# Out:
#      A    B
# 0  100  400
# 1    2    3
# 2    3    2
# 3  400  100

# %%
# specific cloumn
df_replaced = df.replace({'A': 1, 'B': 4}, 100)
df_replaced
# Out:
#      A    B
# 0  100  100
# 1    2    3
# 2    3    2
# 3    4    1

# %%
# multiple values in specific column
df.replace({"A":{1:100} ,"B":{4:200}})
# Out:
#      A    B
# 0  100  200
# 1    2    3
# 2    3    2
# 3    4    1
